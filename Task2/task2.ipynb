# %% [markdown]
# # Project2_Task2
#
# ##### Importing dataframe from task1 csv file.

# %%
import pandas as pd
df = pd.read_csv ('Metadata.csv')
df
# Out:
#                                                  title  \
# 0    Even $1 \times n$ Edge-Matching and Jigsaw Puz...
# 1    NIPS 2016 Tutorial: Generative Adversarial Net...
# 2    Classification of Smartphone Users Using Inter...
# 3    Closed Sets and Operators thereon: Representat...
# 4                       Outlier Robust Online Learning
# ..                                                 ...
# 116  Reinforcement Learning for Flexibility Design ...
# 117  ORDisCo: Effective and Efficient Usage of Incr...
# 118  Representation Learning of Reconstructed Graph...
# 119  If You're Happy, Then You Know It: The Logic o...
# 120  A Provably Efficient Algorithm for Linear Mark...
#
#                                                authors  \
# 0    ['Jeffrey Bosboom', 'Erik D. Demaine', 'Martin...
# 1                                   ['Ian Goodfellow']
# 2    ['Andrey Finkelstein', 'Ron Biton', 'Rami Puzi...
# 3                       ['Carsten Rösnick-Neugebauer']
# 4            ['Jiashi Feng', 'Huan Xu', 'Shie Mannor']
# ..                                                 ...
# 116  ['Yehua Wei', 'Lei Zhang', 'Ruiyi Zhang', 'Shi...
# 117  ['Liyuan Wang', 'Kuo Yang', 'Chongxuan Li', 'L...
# 118  ['Xing Li', 'Wei Wei', 'Xiangnan Feng', 'Zhimi...
# 119                ['Sanaz Azimipour', 'Pavel Naumov']
# 120  ['Minbo Gao', 'Tianle Xie', 'Simon S. Du', 'Li...
#
#                                                summary  \
# 0    We prove the computational intractability of r...
# 1    This report summarizes the tutorial presented ...
# 2    Today, smartphone devices are owned by a large...
# 3    The TTE approach to Computable Analysis is the...
# 4    We consider the problem of learning from noisy...
# ..                                                 ...
# 116  Flexibility design problems are a class of pro...
# 117  Continual learning usually assumes the incomin...
# 118  Graphs are often used to organize data because...
# 119  The article proposes a formal semantics of hap...
# 120  Many real-world applications, such as those in...
#
#                                                comment  \
# 0                                  22 pages, 9 figures
# 1    v2-v4 are all typo fixes. No substantive chang...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 116                                                NaN
# 117                                                NaN
# 118  8 pages, 3 figures. arXiv admin note: text ove...
# 119                                                NaN
# 120                                                NaN
#
#                                            journal_ref  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Logical Methods in Computer Science, Volume 14...
# 4                                                  NaN
# ..                                                 ...
# 116                                                NaN
# 117                                          CVPR 2021
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
#
#                            doi                           entry_id  \
# 0                          NaN  http://arxiv.org/abs/1701.00146v1
# 1                          NaN  http://arxiv.org/abs/1701.00160v4
# 2                          NaN  http://arxiv.org/abs/1701.00220v1
# 3    10.23638/LMCS-14(2:1)2018  http://arxiv.org/abs/1701.00227v4
# 4                          NaN  http://arxiv.org/abs/1701.00251v1
# ..                         ...                                ...
# 116                        NaN  http://arxiv.org/abs/2101.00355v2
# 117                        NaN  http://arxiv.org/abs/2101.00407v2
# 118                        NaN  http://arxiv.org/abs/2101.00417v1
# 119                        NaN  http://arxiv.org/abs/2101.00485v1
# 120                        NaN  http://arxiv.org/abs/2101.00494v1
#
#                        updated                  published primary_category  \
# 0    2016-12-31 17:05:53+00:00  2016-12-31 17:05:53+00:00            cs.CC
# 1    2017-04-03 21:57:48+00:00  2016-12-31 19:17:17+00:00            cs.LG
# 2    2017-01-01 08:12:49+00:00  2017-01-01 08:12:49+00:00            cs.LG
# 3    2018-04-09 07:07:33+00:00  2017-01-01 11:25:42+00:00            cs.CC
# 4    2017-01-01 15:18:13+00:00  2017-01-01 15:18:13+00:00            cs.LG
# ..                         ...                        ...              ...
# 116  2021-01-18 14:35:06+00:00  2021-01-02 02:44:39+00:00            cs.LG
# 117  2021-04-09 01:57:03+00:00  2021-01-02 09:04:14+00:00            cs.LG
# 118  2021-01-02 10:31:14+00:00  2021-01-02 10:31:14+00:00            cs.LG
# 119  2021-01-02 17:42:19+00:00  2021-01-02 17:42:19+00:00            cs.AI
# 120  2021-01-02 18:41:27+00:00  2021-01-02 18:41:27+00:00            cs.LG
#
#                                           categories  \
# 0                                 ['cs.CC', 'cs.CG']
# 1                                          ['cs.LG']
# 2                                 ['cs.LG', 'cs.CR']
# 3    ['cs.CC', 'cs.LO', 'math.LO', '03D15', 'F.4.1']
# 4                               ['cs.LG', 'stat.ML']
# ..                                               ...
# 116                               ['cs.LG', 'cs.AI']
# 117                    ['cs.LG', 'cs.AI', 'stat.ML']
# 118                                        ['cs.LG']
# 119                               ['cs.AI', 'cs.LO']
# 120                    ['cs.LG', 'cs.AI', 'stat.ML']
#
#                                                  links  \
# 0    [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 1    [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 2    [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 3    [arxiv.Result.Link('http://dx.doi.org/10.23638...
# 4    [arxiv.Result.Link('http://arxiv.org/abs/1701....
# ..                                                 ...
# 116  [arxiv.Result.Link('http://arxiv.org/abs/2101....
# 117  [arxiv.Result.Link('http://arxiv.org/abs/2101....
# 118  [arxiv.Result.Link('http://arxiv.org/abs/2101....
# 119  [arxiv.Result.Link('http://arxiv.org/abs/2101....
# 120  [arxiv.Result.Link('http://arxiv.org/abs/2101....
#
#                                pdf_url
# 0    http://arxiv.org/pdf/1701.00146v1
# 1    http://arxiv.org/pdf/1701.00160v4
# 2    http://arxiv.org/pdf/1701.00220v1
# 3    http://arxiv.org/pdf/1701.00227v4
# 4    http://arxiv.org/pdf/1701.00251v1
# ..                                 ...
# 116  http://arxiv.org/pdf/2101.00355v2
# 117  http://arxiv.org/pdf/2101.00407v2
# 118  http://arxiv.org/pdf/2101.00417v1
# 119  http://arxiv.org/pdf/2101.00485v1
# 120  http://arxiv.org/pdf/2101.00494v1
#
# [121 rows x 13 columns]

# %% [markdown]
# ##### Seperating dataframe for different category

# %%
df_LG=df.loc[df['primary_category'] =='cs.LG']
df_LG.head()
# Out:
#                                                title  \
# 1  NIPS 2016 Tutorial: Generative Adversarial Net...
# 2  Classification of Smartphone Users Using Inter...
# 4                     Outlier Robust Online Learning
# 6  Dynamic Deep Neural Networks: Optimizing Accur...
# 9  Two-Bit Networks for Deep Learning on Resource...
#
#                                              authors  \
# 1                                 ['Ian Goodfellow']
# 2  ['Andrey Finkelstein', 'Ron Biton', 'Rami Puzi...
# 4          ['Jiashi Feng', 'Huan Xu', 'Shie Mannor']
# 6                         ['Lanlan Liu', 'Jia Deng']
# 9  ['Wenjia Meng', 'Zonghua Gu', 'Ming Zhang', 'Z...
#
#                                              summary  \
# 1  This report summarizes the tutorial presented ...
# 2  Today, smartphone devices are owned by a large...
# 4  We consider the problem of learning from noisy...
# 6  We introduce Dynamic Deep Neural Networks (D2N...
# 9  With the rapid proliferation of Internet of Th...
#
#                                              comment journal_ref  doi  \
# 1  v2-v4 are all typo fixes. No substantive chang...         NaN  NaN
# 2                                                NaN         NaN  NaN
# 4                                                NaN         NaN  NaN
# 6  fixed typos; updated CIFAR-10 results and adde...         NaN  NaN
# 9                                                NaN         NaN  NaN
#
#                             entry_id                    updated  \
# 1  http://arxiv.org/abs/1701.00160v4  2017-04-03 21:57:48+00:00
# 2  http://arxiv.org/abs/1701.00220v1  2017-01-01 08:12:49+00:00
# 4  http://arxiv.org/abs/1701.00251v1  2017-01-01 15:18:13+00:00
# 6  http://arxiv.org/abs/1701.00299v3  2018-03-05 02:03:00+00:00
# 9  http://arxiv.org/abs/1701.00485v2  2017-01-04 13:54:51+00:00
#
#                    published primary_category            categories  \
# 1  2016-12-31 19:17:17+00:00            cs.LG             ['cs.LG']
# 2  2017-01-01 08:12:49+00:00            cs.LG    ['cs.LG', 'cs.CR']
# 4  2017-01-01 15:18:13+00:00            cs.LG  ['cs.LG', 'stat.ML']
# 6  2017-01-02 00:09:14+00:00            cs.LG  ['cs.LG', 'stat.ML']
# 9  2017-01-02 04:28:16+00:00            cs.LG    ['cs.LG', 'cs.CV']
#
#                                                links  \
# 1  [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 2  [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 4  [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 6  [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 9  [arxiv.Result.Link('http://arxiv.org/abs/1701....
#
#                              pdf_url
# 1  http://arxiv.org/pdf/1701.00160v4
# 2  http://arxiv.org/pdf/1701.00220v1
# 4  http://arxiv.org/pdf/1701.00251v1
# 6  http://arxiv.org/pdf/1701.00299v3
# 9  http://arxiv.org/pdf/1701.00485v2

# %%
df_CC=df.loc[df['primary_category'] =='cs.CC']
df_CC.head()
# Out:
#                                                 title  \
# 0   Even $1 \times n$ Edge-Matching and Jigsaw Puz...
# 3   Closed Sets and Operators thereon: Representat...
# 34  Algorithmically Efficient Syntactic Characteri...
# 35  On the Parameterized Cluster Editing with Vert...
# 80   Coarse-Grained Complexity for Dynamic Algorithms
#
#                                               authors  \
# 0   ['Jeffrey Bosboom', 'Erik D. Demaine', 'Martin...
# 3                      ['Carsten Rösnick-Neugebauer']
# 34  ['Josep Díaz', 'Lefteris Kirousis', 'Sofia Kok...
# 35  ['Faisal N. Abu-Khzam', 'Judith Egan', 'Serge ...
# 80  ['Sayan Bhattacharya', 'Danupon Nanongkai', 'T...
#
#                                               summary  \
# 0   We prove the computational intractability of r...
# 3   The TTE approach to Computable Analysis is the...
# 34  In the field of Judgment Aggrgation, a domain,...
# 35  In the Cluster Editing problem, a given graph ...
# 80  To date, the only way to argue polynomial lowe...
#
#                                               comment  \
# 0                                 22 pages, 9 figures
# 3                                                 NaN
# 34                                           39 pages
# 35                                                NaN
# 80  To be published at SODA 2020. The abstract is ...
#
#                                           journal_ref  \
# 0                                                 NaN
# 3   Logical Methods in Computer Science, Volume 14...
# 34                                                NaN
# 35                                                NaN
# 80                                                NaN
#
#                           doi                           entry_id  \
# 0                         NaN  http://arxiv.org/abs/1701.00146v1
# 3   10.23638/LMCS-14(2:1)2018  http://arxiv.org/abs/1701.00227v4
# 34                        NaN  http://arxiv.org/abs/1901.00138v3
# 35                        NaN  http://arxiv.org/abs/1901.00156v1
# 80                        NaN  http://arxiv.org/abs/2001.00336v1
#
#                       updated                  published primary_category  \
# 0   2016-12-31 17:05:53+00:00  2016-12-31 17:05:53+00:00            cs.CC
# 3   2018-04-09 07:07:33+00:00  2017-01-01 11:25:42+00:00            cs.CC
# 34  2019-09-03 08:45:57+00:00  2019-01-01 11:45:59+00:00            cs.CC
# 35  2019-01-01 14:28:31+00:00  2019-01-01 14:28:31+00:00            cs.CC
# 80  2020-01-02 06:14:54+00:00  2020-01-02 06:14:54+00:00            cs.CC
#
#                                          categories  \
# 0                                ['cs.CC', 'cs.CG']
# 3   ['cs.CC', 'cs.LO', 'math.LO', '03D15', 'F.4.1']
# 34                                        ['cs.CC']
# 35                               ['cs.CC', 'cs.DS']
# 80                               ['cs.CC', 'cs.DS']
#
#                                                 links  \
# 0   [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 3   [arxiv.Result.Link('http://dx.doi.org/10.23638...
# 34  [arxiv.Result.Link('http://arxiv.org/abs/1901....
# 35  [arxiv.Result.Link('http://arxiv.org/abs/1901....
# 80  [arxiv.Result.Link('http://arxiv.org/abs/2001....
#
#                               pdf_url
# 0   http://arxiv.org/pdf/1701.00146v1
# 3   http://arxiv.org/pdf/1701.00227v4
# 34  http://arxiv.org/pdf/1901.00138v3
# 35  http://arxiv.org/pdf/1901.00156v1
# 80  http://arxiv.org/pdf/2001.00336v1

# %%
df_AI=df.loc[df['primary_category'] =='cs.AI']
df_AI.head()
# Out:
#                                                 title  \
# 5                 STRIPS Planning in Infinite Domains
# 7   An affective computational model for machine c...
# 8   Conceptual Spaces for Cognitive Architectures:...
# 15        Game-theoretic Network Centrality: A Review
# 19                Users Constraints in Itemset Mining
#
#                                               authors  \
# 5   ['Caelan Reed Garrett', 'Tomás Lozano-Pérez', ...
# 7                                ['Rohitash Chandra']
# 8   ['Antonio Lieto', 'Antonio Chella', 'Marcello ...
# 15  ['Mateusz K. Tarkowski', 'Tomasz P. Michalak',...
# 19  ['Christian Bessiere', 'Nadjib Lazaar', 'Yahia...
#
#                                               summary  \
# 5   Many robotic planning applications involve con...
# 7   In the past, several models of consciousness h...
# 8   During the last decades, many cognitive archit...
# 15  Game-theoretic centrality is a flexible and so...
# 19  Discovering significant itemsets is one of the...
#
#                                               comment journal_ref  \
# 5                                            11 pages         NaN
# 7                                        under review         NaN
# 8   31 pages, 3 figures in Biologically Inspired C...         NaN
# 15                                                NaN         NaN
# 19                                                NaN         NaN
#
#                            doi                           entry_id  \
# 5                          NaN  http://arxiv.org/abs/1701.00287v2
# 7                          NaN  http://arxiv.org/abs/1701.00349v1
# 8   10.1016/j.bica.2016.10.005  http://arxiv.org/abs/1701.00464v1
# 15                         NaN  http://arxiv.org/abs/1801.00218v1
# 19                         NaN  http://arxiv.org/abs/1801.00345v2
#
#                       updated                  published primary_category  \
# 5   2017-05-28 01:08:00+00:00  2017-01-01 20:37:51+00:00            cs.AI
# 7   2017-01-02 09:48:47+00:00  2017-01-02 09:48:47+00:00            cs.AI
# 8   2017-01-02 17:35:34+00:00  2017-01-02 17:35:34+00:00            cs.AI
# 15  2017-12-31 01:10:39+00:00  2017-12-31 01:10:39+00:00            cs.AI
# 19  2018-02-08 16:21:54+00:00  2017-12-31 19:55:52+00:00            cs.AI
#
#             categories                                              links  \
# 5            ['cs.AI']  [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 7            ['cs.AI']  [arxiv.Result.Link('http://arxiv.org/abs/1701....
# 8            ['cs.AI']  [arxiv.Result.Link('http://dx.doi.org/10.1016/...
# 15  ['cs.AI', 'cs.GT']  [arxiv.Result.Link('http://arxiv.org/abs/1801....
# 19  ['cs.AI', 'cs.DB']  [arxiv.Result.Link('http://arxiv.org/abs/1801....
#
#                               pdf_url
# 5   http://arxiv.org/pdf/1701.00287v2
# 7   http://arxiv.org/pdf/1701.00349v1
# 8   http://arxiv.org/pdf/1701.00464v1
# 15  http://arxiv.org/pdf/1801.00218v1
# 19  http://arxiv.org/pdf/1801.00345v2

# %%
df_AR=df.loc[df['primary_category'] =='cs.AR']
df_AR.head()
# Out:
#                                                 title  \
# 23  Auto-Generation of Pipelined Hardware Designs ...
# 29  High Performance GNR Power Gating for Low-Volt...
# 49  Optimizing Bit-Serial Matrix Multiplication fo...
# 97  Data Criticality in Multi-Threaded Application...
#
#                                               authors  \
# 23      ['Zhiwei Zhong', 'Xiaohu You', 'Chuan Zhang']
# 29  ['Hader E. El-hmaily', 'Rabab Ezz-Eldin', 'A. ...
# 49  ['Yaman Umuroglu', 'Davide Conficconi', 'Lahir...
# 97     ['Abhijit Das', 'John Jose', 'Prabhat Mishra']
#
#                                               summary  \
# 23  This paper presents a general framework for au...
# 29  A robust power gating design using Graphene Na...
# 49  Matrix-matrix multiplication is a key computat...
# 97  Multi-threaded applications are capable of exp...
#
#                                               comment journal_ref  \
# 23                                                NaN         NaN
# 29                   9 pages, 13 Figures and 5 Tables         NaN
# 49  Invited paper at ACM TRETS as extension of FPL...         NaN
# 97                                                NaN         NaN
#
#                 doi                           entry_id  \
# 23              NaN  http://arxiv.org/abs/1801.00472v1
# 29              NaN  http://arxiv.org/abs/1901.00092v1
# 49  10.1145/3337929  http://arxiv.org/abs/1901.00370v2
# 97              NaN  http://arxiv.org/abs/2101.00055v1
#
#                       updated                  published primary_category  \
# 23  2018-01-01 16:50:09+00:00  2018-01-01 16:50:09+00:00            cs.AR
# 29  2019-01-01 04:55:14+00:00  2019-01-01 04:55:14+00:00            cs.AR
# 49  2019-06-11 11:12:17+00:00  2019-01-02 14:05:48+00:00            cs.AR
# 97  2020-12-31 20:13:10+00:00  2020-12-31 20:13:10+00:00            cs.AR
#
#                      categories  \
# 23                    ['cs.AR']
# 29  ['cs.AR', '94C99', 'B.7.1']
# 49                    ['cs.AR']
# 97                    ['cs.AR']
#
#                                                 links  \
# 23  [arxiv.Result.Link('http://arxiv.org/abs/1801....
# 29  [arxiv.Result.Link('http://arxiv.org/abs/1901....
# 49  [arxiv.Result.Link('http://dx.doi.org/10.1145/...
# 97  [arxiv.Result.Link('http://arxiv.org/abs/2101....
#
#                               pdf_url
# 23  http://arxiv.org/pdf/1801.00472v1
# 29  http://arxiv.org/pdf/1901.00092v1
# 49  http://arxiv.org/pdf/1901.00370v2
# 97  http://arxiv.org/pdf/2101.00055v1
